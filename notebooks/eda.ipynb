# %% [markdown]
# # Generated by GitHub Copilot
# # RAVDESS EDA Starter
#
# This notebook is a starter for loading metadata, plotting label distribution, and inspecting waveforms.

# %%
import os
from collections import Counter

root = os.getenv('RAVDESS_PATH', './data/ravdess')
print('Dataset root:', root)
if os.path.exists(root):
    files = [f for f in os.listdir(root) if f.endswith('.wav')]
    print('WAV files found:', len(files))
else:
    print('Dataset path not found. Set RAVDESS_PATH first.')
